# %% [markdown]
# ## Lab 06

# %% [markdown]
# ### Zadanie 1 - Regexy

# %% [markdown]
# Przejdź 15 zadań ze strony http://regexone.com/

# %%
# # Zadanie 1
# # [a-g]
# # Zadanie 2
# # \d\d\d
# # Zadanie 3
# # ...\.
# Zadanie 4
# # [cmf]
# Zadanie 5
# # [dh]
# Zadanie 6
# [A-C]
# Zadanie 7
# [z]{2,5}
# Zadanie 8
# c+
# Zadanie 9
# \?
# Zadanie 10
# \s
# Zadanie 11
# ^Mission
# Zadanie 12
# (file.+)\.pdf$
# Zadanie 13
# (\w+ (\d+))
# Zadanie 14
# (\d+)x(\d+)
# Zadanie 15
# I love (cats|dogs)
# Zadanie 16 (gdzieś ćwiczenia były rozdzielone na dwa przykłady, co musiałem pominąć)
# .*

# %% [markdown]
# ### Zadanie 2 - Regexy

# %% [markdown]
# _Atoms_
#
# Napisz program, który (używając wyrażeń regularnych) przefiltruje plik atoms.log tak by pozostały jedynie linie dot. bezproblemowego przebiegu eksperymentu.
# czyli np. powinny zostać odrzucone takie linie jak
# ```
# RUN 000039 COMPLETED. OUTPUT IN FILE yttrium.dat. 1 UNDERFLOW WARNING.
# ```
# czy
# ```
# RUN 000058 COMPLETED. OUTPUT IN FILE cerium.dat. ALGORITHM DID NOT CONVERGE AFTER 100000 ITERATIONS.
# ```
# można jedynie założyć, że każda linijka pasuje do poniższego schematu
# ```
# RUN [[NUMER Z DOKŁADNIE 6 CYFR]] COMPLETED. OUTPUT IN FILE [[NAZWA]].dat. [[COKOLWIEK]]
# ```

# %%
import re

pattern = r'RUN \d{6} COMPLETED. OUTPUT IN FILE \w+.dat.$'

with open('atoms.log') as atoms:
    for line in atoms:
        if re.match(pattern, line):
            print(line)
# Out:
# RUN 000001 COMPLETED. OUTPUT IN FILE hydrogen.dat.
#
# RUN 000002 COMPLETED. OUTPUT IN FILE helium.dat.
#
# RUN 000003 COMPLETED. OUTPUT IN FILE lithium.dat.
#
# RUN 000004 COMPLETED. OUTPUT IN FILE beryllium.dat.
#
# RUN 000005 COMPLETED. OUTPUT IN FILE boron.dat.
#
# RUN 000006 COMPLETED. OUTPUT IN FILE carbon.dat.
#
# RUN 000007 COMPLETED. OUTPUT IN FILE nitogen.dat.
#
# RUN 000008 COMPLETED. OUTPUT IN FILE oxygen.dat.
#
# RUN 000009 COMPLETED. OUTPUT IN FILE fluorine.dat.
#
# RUN 000010 COMPLETED. OUTPUT IN FILE neon.dat.
#
# RUN 000011 COMPLETED. OUTPUT IN FILE sodium.dat.
#
# RUN 000012 COMPLETED. OUTPUT IN FILE magnesium.dat.
#
# RUN 000013 COMPLETED. OUTPUT IN FILE aluminium.dat.
#
# RUN 000014 COMPLETED. OUTPUT IN FILE silicon.dat.
#
# RUN 000015 COMPLETED. OUTPUT IN FILE phosphorus.dat.
#
# RUN 000016 COMPLETED. OUTPUT IN FILE sulphur.dat.
#
# RUN 000017 COMPLETED. OUTPUT IN FILE chlorine.dat.
#
# RUN 000018 COMPLETED. OUTPUT IN FILE argon.dat.
#
# RUN 000019 COMPLETED. OUTPUT IN FILE potassium.dat.
#
# RUN 000020 COMPLETED. OUTPUT IN FILE calcium.dat.
#
# RUN 000021 COMPLETED. OUTPUT IN FILE scandium.dat.
#
# RUN 000022 COMPLETED. OUTPUT IN FILE titanium.dat.
#
# RUN 000023 COMPLETED. OUTPUT IN FILE vanadium.dat.
#
# RUN 000024 COMPLETED. OUTPUT IN FILE chromium.dat.
#
# RUN 000025 COMPLETED. OUTPUT IN FILE manganese.dat.
#
# RUN 000026 COMPLETED. OUTPUT IN FILE iron.dat.
#
# RUN 000027 COMPLETED. OUTPUT IN FILE cobalt.dat.
#
# RUN 000028 COMPLETED. OUTPUT IN FILE nickel.dat.
#
# RUN 000029 COMPLETED. OUTPUT IN FILE copper.dat.
#
# RUN 000030 COMPLETED. OUTPUT IN FILE zinc.dat.
#
# RUN 000031 COMPLETED. OUTPUT IN FILE gallium.dat.
#
# RUN 000032 COMPLETED. OUTPUT IN FILE germanium.dat.
#
# RUN 000033 COMPLETED. OUTPUT IN FILE arsenic.dat.
#
# RUN 000034 COMPLETED. OUTPUT IN FILE selenium.dat.
#
# RUN 000035 COMPLETED. OUTPUT IN FILE bromine.dat.
#
# RUN 000036 COMPLETED. OUTPUT IN FILE krypton.dat.
#
# RUN 000037 COMPLETED. OUTPUT IN FILE rubidium.dat.
#
# RUN 000038 COMPLETED. OUTPUT IN FILE strontium.dat.
#
# RUN 000049 COMPLETED. OUTPUT IN FILE indium.dat.
#
# RUN 000050 COMPLETED. OUTPUT IN FILE tin.dat.
#
# RUN 000051 COMPLETED. OUTPUT IN FILE antimony.dat.
#
# RUN 000052 COMPLETED. OUTPUT IN FILE tellurium.dat.
#
# RUN 000053 COMPLETED. OUTPUT IN FILE iodine.dat.
#
# RUN 000054 COMPLETED. OUTPUT IN FILE xenon.dat.
#
# RUN 000055 COMPLETED. OUTPUT IN FILE caesium.dat.
#
# RUN 000056 COMPLETED. OUTPUT IN FILE barium.dat.
#
# RUN 000081 COMPLETED. OUTPUT IN FILE thallium.dat.
#
# RUN 000082 COMPLETED. OUTPUT IN FILE lead.dat.
#
# RUN 000083 COMPLETED. OUTPUT IN FILE bismuth.dat.
#
# RUN 000084 COMPLETED. OUTPUT IN FILE polonium.dat.
#
# RUN 000085 COMPLETED. OUTPUT IN FILE astatine.dat.
#
# RUN 000086 COMPLETED. OUTPUT IN FILE radon.dat.
#
# RUN 000087 COMPLETED. OUTPUT IN FILE francium.dat.
#
# RUN 000088 COMPLETED. OUTPUT IN FILE radium.dat.

# %% [markdown]
# ### Zadanie 3 - Regexy

# %% [markdown]
# _Messages_
#
# Napisz program który wypisze linie z logu systemowego "messages.txt" które zawierają informacje o nieprawidłowej nazwie użytkownika (invalid user)

# %%
import locale
locale .setlocale(locale.LC_ALL, 'pl_PL')
import calendar
list(calendar.month_name)
month_abbreviations_map = {
        'Jun': 'czerwiec'
    }
pattern = r'(\w+) (\d+) (\d{2}:\d{2}):(\d{2}) noether sshd\[(\d{5})\]: Invalid user (\w+) from (\d+.\d+.\d+.\d+)'
with open('messages.txt') as messages:
    for line in messages:
        matches = re.search(pattern, line)
        if matches:
            month = calendar.month_name[list(calendar.month_name).index(month_abbreviations_map[matches.group(1)])]
            day = matches.group(2)
            h = matches.group(3)
            user = matches.group(6)
            ip = matches.group(7)
            print(f'Niepoprawna nazwa uzytkownia: "{user}", polaczenie z {ip} nawiazano {day} {month} o godzinie {h}')
# Out:
# Niepoprawna nazwa uzytkownia: "crime", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:49
# Niepoprawna nazwa uzytkownia: "cristi", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cristian", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "curl", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cvsroot", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyber", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cypy", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "cyrus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "daiana", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "dan", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "danger", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "daniel", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "danny", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "darwin", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "data", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "database", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "dave", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "david", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "dea", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "death", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "decoder", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "decrease", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "delete", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "delia", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "demo", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "denis", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "design", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "designer", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "desktop", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "detect", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "detector", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "device", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "dialog", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "diana", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "dido", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "digital", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "dir", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "directive", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:50
# Niepoprawna nazwa uzytkownia: "director", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "disable", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "disk", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "display", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "distributed", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "divx", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "dj", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "dns", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "doctor", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "dolar", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "dolars", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "dolby", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "dollar", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "dollars", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "domain", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "domino", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "down", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "drive", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "driver", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "drives", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "drone", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "earth", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "eddy", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "edgar", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "edit", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "edition", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "editor", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "edu", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "edy", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "effect", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "effects", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "egg", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "electra", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "emergency", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "enable", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "enforcement", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "enter", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "entrie", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "equipment", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "eric", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "esc", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "euro", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "europa", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "european", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "eveline", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "event", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "events", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "exclusive", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "exploit", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "explorer", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "export", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "extract", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "false", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "family", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "fax", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "fedora", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "feedback", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:51
# Niepoprawna nazwa uzytkownia: "ferdinand", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "fernando", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "file", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "film", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "find", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "finish", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "first", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "flight", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "football", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "forum", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "fox", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "francesco", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "frank", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "fred", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "fredy", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "free", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "friend", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "front", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "ftpuser", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "fuck", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "full", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "function", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gabbana", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gabi", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gabriel", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gaby", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "game", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gamma", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gary", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "genius", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "george", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gerald", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gerard", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "ghost", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gilbert", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "girl", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gnome", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "go", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "god", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "google", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gopher", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gouverment", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "gregory", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "group", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:52
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "guest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "gun", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "hack", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "hair", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "halt", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "handsfree", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "hardware", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "harris", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "hawk", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "help", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "hercules", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "hide", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "high", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "history", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "holiday", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "hosting", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "hp", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "http", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "httpd", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "hunter", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "iacob", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "ideal", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "identity", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "igor", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "include", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "increase", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "industry", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "info", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "info", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "infrared", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "input", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "insert", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "inside", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "insomnia", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "intel", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "internet", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "ioan", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "ioana", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "ion", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "ip", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "irc", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "item", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "jack", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "jacob", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "james", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "janette", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "jean", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "jeff", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "jefferson", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "jennifer", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "jeremy", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "jerry", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:53
# Niepoprawna nazwa uzytkownia: "jessie", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "jesus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "jimmy", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "john", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "johnny", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "joker", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "jonnes", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "joseph", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "journal", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "jp", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "julian", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "junk", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "justice", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "kart", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "kernel", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "kevin", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "keygen", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "killer", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "kodak", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "kruth", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "kubuntu", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "lab", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "laboratory", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "lame", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "lamer", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "lan", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "larisa", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "laura", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "laurentiu", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "law", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "led", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "left", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "leo", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "LG", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "library", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "linda", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "linux", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "lion", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "list", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "liviu", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "local", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "localhost", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "lock", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "locked", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "locker", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "login", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "lol", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "lola", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "loser", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "lost", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "mac", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "macarena", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "machine", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "macintosh", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "madonna", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "magic", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "mailbox", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "mailman", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "mailnull", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "make", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "manage", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:54
# Niepoprawna nazwa uzytkownia: "management", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "manual", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "manuel", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mar", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "marcus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "maria", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mariah", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "marius", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mark", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "markus", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "martin", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "marvin", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "massimo", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "master", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "matt", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "max", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "media", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "melanie", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "member", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "memory", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mercedes", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "message", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "method", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "michael", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "micro", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mihai", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mike", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "min", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mircea", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mirel", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "miro", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mobile", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mode", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "model", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "modem", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mohamed", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "money", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "monica", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "monitor", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "monkey", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "montoya", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "moon", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "moon", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "moto", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "motorola", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "msql", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "multimedia", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "mute", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "myra", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "narcis", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "natasha", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "natural", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "nelly", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "network", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "new", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:55
# Niepoprawna nazwa uzytkownia: "nice", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "nicole", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "night", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "nitro", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "number", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oana", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "ocean", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "office", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oliver", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "online", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "opera", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "options", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "oracle", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "orange", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "orbit", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "organization", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "output", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "output", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "own", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "owner", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "ozana", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "pack", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "panasonic", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "panel", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "panorama", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "panther", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "paris", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "pass", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "passwd", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "password", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "paul", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "payne", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "peer", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "pepsi", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "personal", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "pgsql", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:56
# Niepoprawna nazwa uzytkownia: "phantom", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "philip", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "pico", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "pig", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "pink", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "pixel", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "playback", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "player", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "pop", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "power", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "practice", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "preserve", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "president", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "prince", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "princess", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "prison", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "privacy", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "process", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "product", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "produse", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "profile", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "progressive", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "promo", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "protect", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "protection", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "protocol", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "proud", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "proxy", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "ptest", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "purge", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "queen", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "quick", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "quickly", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "rafaelo", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "read", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "reader", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "recruit", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "redhat", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "remember", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "repair", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "repairs", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "reserve", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "reset", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "restore", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "review", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "ricardo", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "richard", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "right", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "ring", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "ringtone", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "ringtones", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "ro", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "robert", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:57
# Niepoprawna nazwa uzytkownia: "robin", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:58
# Niepoprawna nazwa uzytkownia: "robot", polaczenie z 207.54.140.124 nawiazano 25 czerwiec o godzinie 23:58
# ...
# Niepoprawna nazwa uzytkownia: "telnet", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "temp", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "terminal", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "text", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "thomas", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "tiago", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "tiger", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "tim", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "tm", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "tomcat", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "tony", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "tracker", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "trademark", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "transfer", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "trend", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "true", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "tuneup", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "turn", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "turnon", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "tw", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "type", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "unknown", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "unreachable", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "unreal", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "until", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "up", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "upgrade", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "usb", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "use", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "user", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "user", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "username", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "username", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "util", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "utile", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "vali", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "valy", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "vanesa", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "version", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "vicory", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:00
# Niepoprawna nazwa uzytkownia: "victor", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "victoria", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "virus", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "visibility", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "visitor", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "visual", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "vlad", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "walk", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "wanted", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "war", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "water", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "watt", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "wave", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "web", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "webadmin", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "webcam", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "webhosting", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "webmaster", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "webmaster", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "western", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "william", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "willian", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "wizard", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "workshop", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "wrong", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:01
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "www", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "xbox", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "xploit", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "xxx", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "yahoo", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "year", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "young", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zagreb", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zapp", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zero", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zeu", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zeus", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "ziarist", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zimbabwe", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zip", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zlatco", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zlato", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zombie", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zoom", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zorg", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zorro", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "zzz", polaczenie z 207.54.140.124 nawiazano 26 czerwiec o godzinie 00:02
# Niepoprawna nazwa uzytkownia: "test", polaczenie z 202.113.96.15 nawiazano 28 czerwiec o godzinie 19:28

# %% [markdown]
# Przerób program tak, żeby wyświetlał sformatowane komunikaty, tzn.
# ```
# Jun 29 20:18:40 noether sshd[5805]: Invalid user tester from 218.189.194.200
# ```
# powinno zostać przerobione na
# ```
# Niepoprawna nazwa użytkownika: "tester", połaczenie z 218.189.194.200 nawiązano 29 czerwca o godz. 20:18
# ```

# %% [markdown]
# ### Zadanie 4 - Collections
# Uzupenij ponizsze funkcje korzystajac z zaimporotwanych klas

# %%
def count_letters(word):
    """ Zwraca slownik gdzie kluczami sa litery, a wartosci ilosc ich wystepowania """
    dictionary = defaultdict(int)
    for word in word:
        dictionary[word] += 1
    return dictionary


print(count_letters('aaaaa') == {'a': 5})
print(count_letters('abbccaaaa') == {'a': 5, 'b': 2, 'c': 2})
print(count_letters('abc') == {'a': 1, 'b': 1, 'c': 1})
# Out:
# True
# True
# True

# %%
def group_words_by_first_letter(text):
    """ Dzieli tekst po spacjach i zwraca slownik gdzie kluczami sa pierwsze litery, a wartosciami listy slow zaczynajacych sie na te litery"""
    dictionary = defaultdict(list)
    for word in text.split(" "):
        dictionary[word[0]].append(word)
    return dictionary


print(group_words_by_first_letter("ala ma kota") == {'a': ['ala'], 'm': ['ma'], 'k': ['kota']})
print(group_words_by_first_letter("ala ma kota ala ma psa") == {'a': ['ala', 'ala'], 'm': ['ma', 'ma'], 'k': ['kota'], 'p': ['psa']})   
print(group_words_by_first_letter("ala ma kota ale marysia ma konia") == {'a': ['ala', 'ale'], 'm': ['ma', 'marysia', 'ma'], 'k': ['kota', 'konia']})
# Out:
# True
# True
# True

# %% [markdown]
# ### Zadanie 5 - Klasy
# Uzupełnij brakujące metody poniższej klasy.

# %%
class FrozenDictionary(object):
    """
    Odpowiednik frozenset dla zbiorów, czyli słownik, który nie jest modyfikowalny,
    a dzięki temu może być np. elementem zbiorów, albo kluczem w innym słowniku.
    """
    
    def __init__(self, dictionary):
        """Tworzy nowy zamrożony słownik z podanego słownika"""
        self.dict = dictionary
    
    def __hash__(self):
        """Zwraca hasz słownika (int)"""
        return hash(frozenset(self.dict.items()))
    
    def __eq__(self, d):
        """Porównuje nasz słownik z zamrożonym słownikiem d"""
        if isinstance(d, FrozenDictionary):
            return self.__hash__() == d.__hash__()
        return False
    
    def __repr__(self):
        """Zwraca reprezentację naszego słownika jako string"""
        return str(self.dict)

dicts = [FrozenDictionary({'ala': 4}), 
         FrozenDictionary({'ala': 1, 'jacek': 0}),
         FrozenDictionary({'ala': 4}), 
         FrozenDictionary({'ala': 2}), 
         FrozenDictionary({'jacek': 0, 'ala': 1})]

s = set(dicts)
print(dicts[0] == dicts[2])
print(dicts[0] != dicts[3])
print(len(s) == 3)
for d in dicts:
    print(d in s)

# Powinno wyświetlić coś w stylu set([{'ala': 4}, {'ala': 1, 'jacek': 0}, {'ala': 2}])
print(s)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# {{'ala': 1, 'jacek': 0}, {'ala': 2}, {'ala': 4}}

# %% [markdown]
# ### Zadanie 6 - Bag of Words
# Napisz klasę "Bag of words", która będzie "workiem słów" z zadanego dokumentu. Oznacza to, że ma w sobie przechowywać informacje o tym ile razy każde słowo wystąpiło w dokumencie. Dodatkowo ma udostępniać następującą funkcjonalność:
# * Można utworzyć go na dwa sposoby:
# ```
# bow = BagOfWords("ala ma kota ala ma ala")
# bow = BagOfWords(open("plik.txt"))
# ```
# * Możliwość wyświetlania go po prostu pisząc print(bow) (kolejność taka sama jak przy przeglądaniu forem)
# ```
# ala:3, ma:2, kota:1
# ```
# * Sprawdzanie czy jakieś słowo należy do naszego worka pisząc
# ```
# if 'ala' in bow:
#     ...
# ```
# * Przeglądanie słów w worku od najczęściej do najrzadziej występującego, czyli
# ```
# for word in bow:
#   print(word)
# ```
#     powinniśmy zobaczyć
# ```
# ala
# ma
# kota
# ```
# * Możliwość dodawania dwóch worków, pisząc
# ```
# bow1 = BagOfWords("ala ma kota ala ma ala")
# bow2 = BagOfWords("tomek tez ma kota")
# bow3 = bow1 + bow2
# print('tomek' in bow1) # False
# print('tomek' in bow3) # True
# print('ala' in bow3) # True
# print(bow3) # ala:3, ma:3, kota:2, tez:1, tomek:1
#     ```
# * Odczytywanie częstości wystąpień słów poprzez nawiasy kwadratowe
# ```
# print(bow1["ala"]) # 3
# print(bow3["ala"]) # 3
# ```
# * Aktualizację cześtości wystąpień
# ```
# bow3['tomek'] = 10
# for el in bow3:
#     print el
# ```
#     powinno wyświetlić najpierw `tomek`

# %%
from collections import defaultdict

class BagOfWords:
    def __init__(self, initializer=None):
        self.dict = defaultdict(lambda: 0)
        if isinstance(initializer, str):
            for word in initializer.split():
                self.dict[word] += 1
        elif initializer is not None:
            for line in initializer:
                for word in line.split():
                    self.dict[word] += 1

    def __getitem__(self, item):
        return self.dict[item]

    def __setitem__(self, key, value):
        self.dict[key] = value

    def __add__(self, other):
        new_bag = BagOfWords()
        for k in other:
            new_bag[k] += other[k]
        for k, v in self.dict.items():
            new_bag[k] += v
        return new_bag

    def __iter__(self):
        words = defaultdict(lambda: set())
        for k, v in self.dict.items():
            words[v].add(k)
        for count in reversed(sorted(words.keys())):
            for word in words[count]:
                yield word
        return

    def __repr__(self):
        return ', '.join([f'{key}:{self[key]}' for key in self])

bow1 = BagOfWords("ala ma kota ala ma ala")
bow2 = BagOfWords(open('text.txt'))
print(bow1)
print(bow2)

if 'ala' in bow1:
    print('ala')

bow3 = bow1 + bow2
print(bow3)
print(bow1['ala'])

ala = 'ala'
if ala in bow1:
    print(ala)
# Out:
# ala:3, ma:2, kota:1
# na:1, Zbiegniew:1, Władysław:1, psa.:1, kota,:1, a:1
# ala
# ala:3, ma:2, na:1, Zbiegniew:1, Władysław:1, psa.:1, kota:1, kota,:1, a:1
# 3
# ala
